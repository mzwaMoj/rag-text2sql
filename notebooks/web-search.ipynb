# %%
import requests
import firecrawl

# Step 1: Fetch search results from Brave Search API
response = requests.get('https://api.search.brave.com/v1/search', params={'q': 'your_query'})
search_results = response.json()

# Step 2: Extract URLs from search results
urls = [result['url'] for result in search_results['results']]

# Step 3: Scrape data using Firecrawl
scraped_data = []
for url in urls:
    data = firecrawl.scrape(url)
    scraped_data.append(data)

# Step 4: Process the scraped data
# (Your data processing logic here)

# %%
pip install firecrawl-py

# %%
import requests
from firecrawl import FirecrawlApp, ScrapeOptions

# Initialize Firecrawl with your API key
firecrawl_app = FirecrawlApp(api_key="fc-YOUR_API_KEY")

def fetch_search_results(query):
    # Fetch search results from Brave Search API
    response = requests.get('https://api.search.brave.com/v1/search', params={'q': query})
    search_results = response.json()
    return search_results

def extract_urls(search_results):
    # Extract URLs from search results
    urls = [result['url'] for result in search_results['results']]
    return urls

def scrape_data(urls):
    # Scrape data using Firecrawl
    scraped_data = []
    for url in urls:
        data = firecrawl_app.scrape_url(url, formats=['markdown', 'html'])
        scraped_data.append(data)
    return scraped_data
def process_data(scraped_data):
    # Process the scraped data (example: print the data)
    for data in scraped_data:
        print(data)

# Example usage
query = 'your_query'
search_results = fetch_search_results(query)
urls = extract_urls(search_results)
scraped_data = scrape_data(urls)
process_data(scraped_data)

# %%
import requests
from firecrawl import FirecrawlApp, ScrapeOptions

# Initialize Firecrawl with your API key
firecrawl_app = FirecrawlApp(api_key="fc-YOUR_API_KEY")

def fetch_search_results(query):
    # Fetch search results from Brave Search API
    response = requests.get('https://api.search.brave.com/v1/search', params={'q': query})
    search_results = response.json()
    return search_results

def extract_urls(search_results):
    # Extract URLs from search results
    urls = [result['url'] for result in search_results['results']]
    return urls

def scrape_data(urls):
    # Scrape data using Firecrawl
    scraped_data = []
    for url in urls:
        data = firecrawl_app.scrape_url(url, formats=['markdown', 'html'])
        scraped_data.append(data)
    return scraped_data

def process_data(scraped_data):
    # Process the scraped data (example: print the data)
    for data in scraped_data:
        print(data)

# Example usage
query = 'your_query'
search_results = fetch_search_results(query)
urls = extract_urls(search_results)
scraped_data = scrape_data(urls)
process_data(scraped_data)
